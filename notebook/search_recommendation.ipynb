# %% [markdown]
# ## Search Recommendation

# %%
import os
import yaml
import openai

with open('./environment.yaml', 'r') as f:
    env = yaml.safe_load(f)
    os.environ.update(env)

# %%
openai.api_key = os.environ['OPENAI_API_KEY']
openai.api_base = os.environ['OPENAI_API_BASE']

# %%
import pandas as pd

original_data = pd.read_excel('./泰国-hm.xlsx', header=1).drop(columns='备注').fillna('None')

# %%
original_data
# Out:
#                    检测领域               领域关键词                       搜索样例
# 0         Type Approval               Auto     thailand DLT consulting
# 1          Homologation             Vehicle    thai vehicle inspection
# 2           Certificate    Electric vehicle          thai homologation
# 3                 Cert   Autonomous driving   thai vehicle consulting
# 4              Approval                 DLT       thailand DLT service
# 5            Consulting                TISI  thai emission testing lab
# 6                 REACH                None                       None
# 7   Chemical regulation                None                       None
# 8            inspection                None                       None
# 9              emmision                None                       None
# 10          Testing lab                None                       None

# %%
original_data['领域关键词']
# Out:
# 0                  Auto
# 1                Vehicle
# 2       Electric vehicle
# 3     Autonomous driving
# 4                    DLT
# 5                   TISI
# 6                   None
# 7                   None
# 8                   None
# 9                   None
# 10                  None
# Name: 领域关键词, dtype: object

# %%
from typing import Optional
from langchain.chains.openai_functions import (
    create_structured_output_chain,
)
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.schema import HumanMessage, SystemMessage

# %%
from pydantic import BaseModel, Field
from typing import Optional


# Base Class
class SearchRecommendation(BaseModel):
    search_keywords: list[str] = Field(..., title="Search Keywords about the topic. Less than 3.")
    search_query: list[str] = Field(..., title="Search Query about the topic. Less than 3.")
    search_query_thai: list[str] = Field(..., title="Search Query about the topic in Thai language. Less than 3.")

# %%
# If we pass in a model explicitly, we need to make sure it supports the OpenAI function-calling API.
llm = ChatOpenAI(model="gpt-4", 
                 temperature=0.7)

system_message = SystemMessage(
        content="You are Chat-GPT, assisting third-party inspection personnel in searching for updates on third-party testing standards in the corresponding country and professional field. By using the provided professional keywords(maybe not provided) in special filed, you generate similar professional keywords that have similar semantic meanings. Then you help them organize multiple effective queries in search engines using these keywords.")
human_message = HumanMessage(
        content="Generate different inquiry methods based on the {testing_field} and professional {domain_keywords} similar to the {search_example}. They should effectively assist me in filtering out the new standards or regulations in the corresponding {testing_field} in Thailand when using a search engine. Note that your recommendation for search query must has a strong relationship with {testing_field} and {domain_keywords}"
)

# %%
prompt_msgs = [system_message, human_message, HumanMessagePromptTemplate.from_template("{input}")]
prompt = ChatPromptTemplate(messages=prompt_msgs)
chain = create_structured_output_chain(SearchRecommendation, llm, prompt, verbose=False)

# %%
res = []
for i in range(len(original_data)):
    input_query = '{testing_field}: ' + original_data['检测领域'][i] + '\n' + '{domain_keywords}: ' + original_data['领域关键词'][i] + '\n' + '{search_example}: ' + original_data['搜索样例'][i]
    res_part = chain.run(input_query)
    print(res_part)
    res.append(res_part)
    # print(original_data['检测领域'][i])
# Out:
# search_keywords=['Thailand Vehicle Type Approval', 'Thai Automobile Regulations', 'Vehicle Certification Thailand', 'Thai Auto Standards', 'Automotive Compliance Thailand'] search_query=['Thailand Vehicle Type Approval updates', 'Current Thai Automobile Regulations', 'Latest updates in Vehicle Certification Thailand', 'Thai Auto Standards changes', 'New Automotive Compliance standards in Thailand'] search_query_thai=['ปรับปรุงล่าสุดของการอนุมัติประเภทของยานพาหนะในประเทศไทย', 'กฎระเบียบรถยนต์ไทยปัจจุบัน', 'ปรับปรุงล่าสุดในการรับรองยานพาหนะในประเทศไทย', 'การเปลี่ยนแปลงมาตรฐานรถยนต์ไทย', 'มาตรฐานการปฏิบัติงานทางยานยนต์ใหม่ในประเทศไทย']
# search_keywords=['Thailand Homologation Standards', 'Vehicle Homologation norms in Thailand', 'Thailand Vehicle Regulation', 'Vehicle Testing Procedures in Thailand', 'Thai Homologation updates', 'Vehicle Certification in Thailand', 'Vehicle Compliance in Thailand', 'Thai Vehicle testing standards'] search_query=['latest Thailand Homologation Standards for Vehicles', 'recent Vehicle Homologation norms in Thailand', 'new Thailand Vehicle Regulation updates', 'current Vehicle Testing Procedures in Thailand', 'Thai Homologation updates for vehicles', 'Vehicle Certification standards in Thailand', 'updated Vehicle Compliance laws in Thailand', 'latest Thai Vehicle testing standards'] search_query_thai=['มาตรฐานการรับรองการทดสอบยานพาหนะในประเทศไทยล่าสุด', 'กฎหมายการรับรองยานพาหนะในประเทศไทยล่าสุด', 'มาตรฐานการทดสอบยานพาหนะในประเทศไทยใหม่', 'ขั้นตอนการทดสอบยานพาหนะในประเทศไทยปัจจุบัน', 'การอัปเดตการรับรองยานพาหนะในประเทศไทย', 'มาตรฐานการรับรองยานพาหนะในประเทศไทย', 'กฎหมายใหม่เกี่ยวกับการปฏิบัติตามข้อกำหนดของยานพาหนะในประเทศไทย', 'มาตรฐานการทดสอบยานพาหนะในประเทศไทยล่าสุด']
# search_keywords=['EV certificate', 'electric vehicle homologation', 'EV testing standards', 'electric car certification', 'Thailand EV regulations', 'Thai EV conformity'] search_query=['latest EV certificate regulations in Thailand', 'newest Thailand electric vehicle homologation standards', 'recent updates in EV testing standards in Thailand', 'changes in electric car certification in Thailand', 'current Thailand EV regulations', 'Thai EV conformity newest updates'] search_query_thai=['กฎระเบียบใบรับรอง EV ล่าสุดในประเทศไทย', 'มาตรฐานการรับรองรถยนต์ไฟฟ้าใหม่ล่าสุดในประเทศไทย', 'การอัพเดทล่าสุดในมาตรฐานการทดสอบ EV ในประเทศไทย', 'การเปลี่ยนแปลงในการรับรองรถยนต์ไฟฟ้าในประเทศไทย', 'กฎระเบียบ EV ปัจจุบันในประเทศไทย', 'การปรับปรุงล่าสุดในความสอดคล้องกับ EV ของประเทศไทย']
# search_keywords=['autonomous driving certification', 'self-driving vehicle regulations', 'autonomous vehicle testing standards', 'driverless car certification Thailand', 'AI driving regulation updates', 'machine learning in vehicle certification'] search_query=['Thailand autonomous driving certification updates', 'Latest self-driving vehicle regulations in Thailand', 'New autonomous vehicle testing standards in Thailand', 'Driverless car certification updates in Thailand', 'Recent AI driving regulation changes in Thailand', 'Machine learning in vehicle certification standards in Thailand'] search_query_thai=['การอัปเดตการรับรองการขับขี่อัตโนมัติในประเทศไทย', 'ระเบียบการขับขี่รถยนต์อัตโนมัติล่าสุดในประเทศไทย', 'มาตรฐานการทดสอบรถยนต์อัตโนมัติใหม่ในประเทศไทย', 'การอัปเดตการรับรองรถยนต์ไม่มีคนขับในประเทศไทย', 'การเปลี่ยนแปลงระเบียบข้อบังคับการขับขี่ AI ล่าสุดในประเทศไทย', 'มาตรฐานในการรับรองการขับขี่ด้วยเครื่องเรียนรู้ของเครื่องในประเทศไทย']
# search_keywords=['Thailand DLT', 'Approval', 'Regulations', 'Standards', 'New Updates', 'Compliance', 'Third-party testing'] search_query=['Thailand DLT Approval Regulations New Updates', 'Thailand DLT Approval Standards Updates', 'Thailand DLT Approval Compliance', 'Thailand DLT Third-party testing New Standards', 'New Regulations in Thailand DLT Approval'] search_query_thai=['การอนุมัติ DLT ในประเทศไทย มาตรฐาน การปรับปรุงใหม่', 'การอนุมัติ DLT ในประเทศไทย กฎระเบียบ การปรับปรุงใหม่', 'การอนุมัติ DLT ในประเทศไทย การปฏิบัติตาม', 'การทดสอบของบุคคลที่สาม DLT ในประเทศไทย มาตรฐานใหม่', 'กฎระเบียบใหม่ในการอนุมัติ DLT ในประเทศไทย']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 4
#       2 for i in range(len(original_data)):
#       3     input_query = '{testing_field}: ' + original_data['检测领域'][i] + '\n' + '{domain_keywords}: ' + original_data['领域关键词'][i] + '\n' + '{search_example}: ' + original_data['搜索样例'][i]
# ----> 4     res_part = chain.run(input_query)
#       5     print(res_part)
#       6     res.append(res_part)
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/chains/base.py:440, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     438     if len(args) != 1:
#     439         raise ValueError("`run` supports only one positional argument.")
# --> 440     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     441         _output_key
#     442     ]
#     444 if kwargs and not args:
#     445     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     446         _output_key
#     447     ]
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/chains/base.py:243, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
# --> 243     raise e
#     244 run_manager.on_chain_end(outputs)
#     245 final_outputs: Dict[str, Any] = self.prep_outputs(
#     246     inputs, outputs, return_only_outputs
#     247 )
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/chains/base.py:237, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     231 run_manager = callback_manager.on_chain_start(
#     232     dumpd(self),
#     233     inputs,
#     234 )
#     235 try:
#     236     outputs = (
# --> 237         self._call(inputs, run_manager=run_manager)
#     238         if new_arg_supported
#     239         else self._call(inputs)
#     240     )
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/chains/llm.py:93, in LLMChain._call(self, inputs, run_manager)
#      87 def _call(
#      88     self,
#      89     inputs: Dict[str, Any],
#      90     run_manager: Optional[CallbackManagerForChainRun] = None,
#      91 ) -> Dict[str, str]:
#      92     response = self.generate([inputs], run_manager=run_manager)
# ---> 93     return self.create_outputs(response)[0]
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/chains/llm.py:217, in LLMChain.create_outputs(self, llm_result)
#     215 def create_outputs(self, llm_result: LLMResult) -> List[Dict[str, Any]]:
#     216     """Create outputs from response."""
# --> 217     result = [
#     218         # Get the text of the top generated string.
#     219         {
#     220             self.output_key: self.output_parser.parse_result(generation),
#     221             "full_generation": generation,
#     222         }
#     223         for generation in llm_result.generations
#     224     ]
#     225     if self.return_final_only:
#     226         result = [{self.output_key: r[self.output_key]} for r in result]
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/chains/llm.py:220, in <listcomp>(.0)
#     215 def create_outputs(self, llm_result: LLMResult) -> List[Dict[str, Any]]:
#     216     """Create outputs from response."""
#     217     result = [
#     218         # Get the text of the top generated string.
#     219         {
# --> 220             self.output_key: self.output_parser.parse_result(generation),
#     221             "full_generation": generation,
#     222         }
#     223         for generation in llm_result.generations
#     224     ]
#     225     if self.return_final_only:
#     226         result = [{self.output_key: r[self.output_key]} for r in result]
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/output_parsers/openai_functions.py:97, in PydanticAttrOutputFunctionsParser.parse_result(self, result)
#      96 def parse_result(self, result: List[Generation]) -> Any:
# ---> 97     result = super().parse_result(result)
#      98     return getattr(result, self.attr_name)
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/output_parsers/openai_functions.py:80, in PydanticOutputFunctionsParser.parse_result(self, result)
#      79 def parse_result(self, result: List[Generation]) -> Any:
# ---> 80     _result = super().parse_result(result)
#      81     if self.args_only:
#      82         pydantic_args = self.pydantic_schema.parse_raw(_result)  # type: ignore
#
# File ~/opt/miniconda3/envs/sgs_openai/lib/python3.11/site-packages/langchain/output_parsers/openai_functions.py:28, in OutputFunctionsParser.parse_result(self, result)
#      26 message = generation.message
#      27 try:
# ---> 28     func_call = message.additional_kwargs["function_call"]
#      29 except ValueError as exc:
#      30     raise OutputParserException(f"Could not parse function call: {exc}")
#
# KeyError: 'function_call'

# %%
original_data
# Out:
#                    检测领域               领域关键词                       搜索样例
# 0         Type Approval               Auto     thailand DLT consulting
# 1          Homologation             Vehicle    thai vehicle inspection
# 2           Certificate    Electric vehicle          thai homologation
# 3                 Cert   Autonomous driving   thai vehicle consulting
# 4              Approval                 DLT       thailand DLT service
# 5            Consulting                TISI  thai emission testing lab
# 6                 REACH                None                       None
# 7   Chemical regulation                None                       None
# 8            inspection                None                       None
# 9              emmision                None                       None
# 10          Testing lab                None                       None

# %%
original_data[['搜索关键词（推荐）', '搜索样例推荐（英语）', '搜索样例推荐（泰语）']] = '', '', ''

# %%
original_data.iloc[0:1]
# Out:
#             检测领域  领域关键词                     搜索样例 搜索关键词（推荐） 搜索样例推荐（英语）  \
# 0  Type Approval  Auto   thailand DLT consulting
#
#   搜索样例推荐（泰语）
# 0

# %%
res[0].search_keywords
# Out:
# ['Thailand Vehicle Type Approval',
#  'Thai Automobile Regulations',
#  'Vehicle Certification Thailand',
#  'Thai Auto Standards',
#  'Automotive Compliance Thailand']

# %%
new_res = []
for i in range(len(original_data)):
    assert len(res[i].search_query) == len(res[i].search_query_thai)
    new_df = pd.concat([original_data[i:i + 1].copy()]*(len(res[i].search_query)), axis=0)
    for j in range(len(res[i].search_query)):
        new_df.iloc[j, -3] = ' / '.join(res[i].search_keywords)
        new_df.iloc[j, -2] = res[i].search_query[j]  # 使用整数索引进行赋值
        new_df.iloc[j, -1] = res[i].search_query_thai[j]  # 使用整数索引进行赋值
    new_res.append(new_df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 3
#       1 new_res = []
#       2 for i in range(len(original_data)):
# ----> 3     assert len(res[i].search_query) == len(res[i].search_query_thai)
#       4     new_df = pd.concat([original_data[i:i + 1].copy()]*(len(res[i].search_query)), axis=0)
#       5     for j in range(len(res[i].search_query)):
#
# IndexError: list index out of range

# %%
new_res[0]
# Out:
#             检测领域  领域关键词                     搜索样例  \
# 0  Type Approval  Auto   thailand DLT consulting
# 0  Type Approval  Auto   thailand DLT consulting
# 0  Type Approval  Auto   thailand DLT consulting
#
#                                            搜索关键词（推荐）  \
# 0  Type Approval / Auto / standards / regulations...
# 0  Type Approval / Auto / standards / regulations...
# 0  Type Approval / Auto / standards / regulations...
#
#                                           搜索样例推荐（英语）  \
# 0  Type Approval standards and regulations in Tha...
# 0             Auto Type Approval updates in Thailand
# 0           DLT Type Approval consulting in Thailand
#
#                                           搜索样例推荐（泰语）
# 0     มาตรฐานและกฎระเบียบการอนุมัติประเภทในประเทศไทย
# 0            อัปเดตการอนุมัติประเภทรถยนต์ในประเทศไทย
# 0  การให้คำปรึกษาในการอนุมัติประเภทจากกรมการขนส่ง...

# %%
final_res = pd.concat(new_res).groupby(['检测领域', '领域关键词', '搜索样例', '搜索关键词（推荐）', '搜索样例推荐（英语）']).agg({'搜索样例推荐（泰语）': lambda x: x,})

# %%
final_res
# Out:
#                                                                                                                                                                                     搜索样例推荐（泰语）
# 检测领域       领域关键词 搜索样例                 搜索关键词（推荐）                                          搜索样例推荐（英语）
# Approval   DLT   thailand DLT service Thailand DLT approval / DLT service approval in... Changing standards for DLT testing service in T...  การเปลี่ยนแปลงมาตรฐานสำหรับบริการทดสอบ DLT ในป...
#                                                                                          Current approval standards for DLT in Thailand        มาตรฐานการอนุมัติปัจจุบันสำหรับ DLT ในประเทศไทย
#                                                                                          Latest DLT approval requirements in Thailand            ความต้องการในการอนุมัติ DLT ล่าสุดในประเทศไทย
#                                                                                          Latest Thailand DLT approval standards                       มาตรฐานการอนุมัติ DLT ล่าสุดของประเทศไทย
#                                                                                          New DLT service approval regulations in Thailand    ข้อบังคับใหม่เกี่ยวกับการอนุมัติบริการ DLT ในป...
# ...                                                                                                                                                                                        ...
# inspection None  None                 inspection standards / inspection regulations /... latest inspection guidelines in Thailand                            แนวทางการตรวจสอบล่าสุดในประเทศไทย
#                                                                                          new inspection procedures in Thailand                                 กระบวนการตรวจสอบใหม่ในประเทศไทย
#                                                                                          new inspection regulations in Thailand                               ระเบียบการตรวจสอบใหม่ในประเทศไทย
#                                                                                          recent inspection standards in Thailand                            มาตรฐานการตรวจสอบล่าสุดในประเทศไทย
#                                                                                          updated Thailand inspection requirements              ข้อกำหนดการตรวจสอบในประเทศไทยที่ได้รับการอัปเดต
#
# [69 rows x 1 columns]

# %%
final_res.to_excel('final_res.xlsx')

# %%
final_res
# Out:
#                                                                                                                                                                   搜索样例推荐（泰语）
# 检测领域       领域关键词 搜索样例                 搜索关键词（推荐）                                          搜索样例推荐（英语）
# Approval   DLT   thailand DLT service new regulations / latest standards / updated re... DLT guidelines in Thailand                                   แนวทาง DLT ในประเทศไทย
#                                                                                          DLT regulations in Thailand                               กฎระเบียบ DLT ในประเทศไทย
#                                                                                          Thailand approval requirements                  ข้อกำหนดการอนุมัติประเภทในประเทศไทย
#                                                                                          Thailand approval rules                          กฎเกณฑ์การอนุมัติประเภทในประเทศไทย
#                                                                                          Thailand approval standards                      มาตรฐานการอนุมัติประเภทในประเทศไทย
# ...                                                                                                                                                                      ...
# emmision   None  None                 emission testing standards Thailand / emission ... new emission standards Thailand                    มาตรฐานการปล่อยก๊าซใหม่ Thailand
# inspection None  None                 inspection standards Thailand / inspection regu... inspection regulations in Thailand                   กฎระเบียบการตรวจสอบในประเทศไทย
#                                                                                          inspection standards in Thailand                       มาตรฐานการตรวจสอบในประเทศไทย
#                                                                                          new inspection standards in Thailand               มาตรฐานการตรวจสอบใหม่ในประเทศไทย
#                                                                                          updated inspection regulations in Thailand  กฎระเบียบการตรวจสอบที่อัปเดตในประเทศไทย
#
# [67 rows x 1 columns]

# %% [markdown]
# ## Google Search

# %%
import pandas as pd

key_words = pd.read_excel('../data/res.xlsx')

# %%
from collections import defaultdict

field_keyword_dict = defaultdict(list)
key = None
for i in range(len(key_words)):
    if not pd.isna(key_words['检测领域'][i]):
        key = key_words['检测领域'][i]
    if pd.isna(key_words['合格'][i]):
        search_ele_en = key_words['搜索样例推荐（英语）'][i]
        search_ele_tai = key_words['搜索样例推荐（泰语）'][i] if not pd.isna(key_words['搜索样例推荐（泰语）'][i]) else None
        field_keyword_dict[key].append([search_ele_en, search_ele_tai])

# %%
key_words
# Out:
#         检测领域 领域关键词                  搜索样例  \
# 0   Approval   DLT  thailand DLT service
# 1        NaN   NaN                   NaN
# 2        NaN   NaN                   NaN
# 3        NaN   NaN                   NaN
# 4        NaN   NaN                   NaN
# ..       ...   ...                   ...
# 63       NaN   NaN                   NaN
# 64       NaN   NaN                   NaN
# 65       NaN   NaN                   NaN
# 66       NaN   NaN                   NaN
# 67       NaN   NaN                   NaN
#
#                                             搜索关键词（推荐）  \
# 0   approval standards Thailand / regulations for ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
#
#                                 搜索样例推荐（英语）  \
# 0               DLT accreditation Thailand
# 1                  DLT approval guidelines
# 2            DLT approval process Thailand
# 3                DLT approval requirements
# 4                     DLT approval updates
# ..                                     ...
# 63  latest inspection regulations Thailand
# 64       new inspection standards Thailand
# 65             Auto consulting in Thailand
# 66          Vehicle consulting in Thailand
# 67       Vehicle certification in Thailand
#
#                             搜索样例推荐（泰语）   合格
# 0              การรับรอง DLT ประเทศไทย    N
# 1                 แนวทางการอนุมัติ DLT  NaN
# 2     กระบวนการอนุมัติ DLT ในประเทศไทย  NaN
# 3               ข้อกำหนดการอนุมัติ DLT  NaN
# 4                 อัปเดตการอนุมัติ DLT  NaN
# ..                                 ...  ...
# 63  กฎระเบียบการตรวจสอบล่าสุดประเทศไทย    N
# 64      มาตรฐานการตรวจสอบใหม่ประเทศไทย    N
# 65                                 NaN  NaN
# 66                                 NaN  NaN
# 67                                 NaN  NaN
#
# [68 rows x 7 columns]

# %%
field_keyword_dict
# Out:
# defaultdict(list,
#             {'Approval': [['DLT approval guidelines', 'แนวทางการอนุมัติ DLT'],
#               ['DLT approval process Thailand',
#                'กระบวนการอนุมัติ DLT ในประเทศไทย'],
#               ['DLT approval requirements', 'ข้อกำหนดการอนุมัติ DLT'],
#               ['DLT approval updates', 'อัปเดตการอนุมัติ DLT'],
#               ['DLT certification Thailand', 'การรับรอง DLT ประเทศไทย']],
#              'Cert ': [['Thailand autonomous driving regulations update',
#                'ประมวลกฎหมายการขับรถไร้คนขับในประเทศไทย'],
#               ['Thailand autonomous driving standards and regulations',
#                'มาตรฐานและกฎหมายการขับรถยนต์ไร้คนขับในประเทศไทย'],
#               ['Thailand certification standards for autonomous driving',
#                'มาตรฐานการรับรองในประเทศไทยสำหรับรถยนต์ไร้คนขับ'],
#               ['Thailand vehicle consulting for cert testing',
#                'การให้คำปรึกษารถยนต์ในประเทศไทยสำหรับการรับรอง']],
#              'Certificate': [['Thai regulations on electric vehicle certification',
#                'กฎระเบียบไทยเกี่ยวกับการรับรองใบรับรองสำหรับยานพาหนะไฟฟ้า'],
#               ['Thailand electric vehicle certificate requirements',
#                'ข้อกำหนดใบรับรองสำหรับยานพาหนะไฟฟ้าในประเทศไทย'],
#               ['electric vehicle homologation standards in Thailand',
#                'มาตรฐานการโฮโมโลเกชันสำหรับยานพาหนะไฟฟ้าในประเทศไทย'],
#               ['homologation process for electric vehicles in Thailand',
#                'กระบวนการโฮโมโลเกชันสำหรับยานพาหนะไฟฟ้าในประเทศไทย'],
#               ['latest regulations for electric vehicle certification in Thailand',
#                'กฎระเบียบล่าสุดสำหรับการรับรองใบรับรองสำหรับยานพาหนะไฟฟ้าในประเทศไทย'],
#               ['new certificate regulations for electric vehicles in Thailand',
#                'ข้อมูลกฎระเบียบใหม่สำหรับการรับรองใบรับรองสำหรับยานพาหนะไฟฟ้าในประเทศไทย']],
#              'Chemical regulation': [['current chemical compliance standards Thailand',
#                'มาตรฐานการปฏิบัติตามกฎระเบียบสารเคมีประเทศไทย']],
#              'Homologation': [['Thailand homologation standards',
#                'มาตรฐานการรับรองในการเข้าสู่ระบบในประเทศไทย'],
#               ['Thailand vehicle certification process',
#                'กระบวนการรับรองยานพาหนะในประเทศไทย'],
#               ['homologation bodies in Thailand',
#                'หน่วยงานที่รับรองการเข้าสู่ระบบในประเทศไทย'],
#               ['homologation regulations in Thailand',
#                'กฎระเบียบการรับรองในการเข้าสู่ระบบในประเทศไทย'],
#               ['vehicle testing requirements in Thailand',
#                'ข้อกำหนดในการทดสอบยานพาหนะในประเทศไทย']],
#              'REACH': [['REACH regulations Thailand',
#                'กฎระเบียบ REACH ประเทศไทย'],
#               ['REACH standards Thailand', 'มาตรฐาน REACH ประเทศไทย'],
#               ['new REACH requirements Thailand',
#                'ข้อกำหนด REACH ใหม่ ประเทศไทย']],
#              'Type Approval': [['type approval agency for auto in Thailand',
#                'หน่วยงานการรับรองประเภทสำหรับยานยนต์ในประเทศไทย'],
#               ['type approval process for vehicles in Thailand',
#                'กระบวนการการรับรองประเภทสำหรับยานยนต์ในประเทศไทย'],
#               ['type approval requirements for automotive in Thailand',
#                'ข้อกำหนดการรับรองประเภทสำหรับยานยนต์ในประเทศไทย']],
#              'emmision': [['current industrial emission standards in Thailand',
#                'มาตรฐานการปล่อยก๊าซพลังงานอุตสาหกรรมปัจจุบันในประเทศไทย'],
#               ['latest emission regulations in Thailand',
#                'กฎระเบียบการปล่อยก๊าซพลังงานล่าสุดในประเทศไทย'],
#               ['new emission standards in Thailand',
#                'มาตรฐานการปล่อยก๊าซพลังงานในประเทศไทย'],
#               ['recent vehicle emission standards in Thailand',
#                'มาตรฐานการปล่อยก๊าซพลังงานยานยนต์ล่าสุดในประเทศไทย']],
#              'inspection': [['Auto consulting in Thailand', None],
#               ['Vehicle consulting in Thailand', None],
#               ['Vehicle certification in Thailand', None]]})

# %%
import aiohttp
import json
import asyncio
import nest_asyncio
import random

nest_asyncio.apply()

async def get_google_result(query):
    # await asyncio.sleep(random.randint(1, 5))
    url = "https://google.serper.dev/search"
    payload = json.dumps({
      "q": query,
      "num": 20,
    })
    headers = {
        'X-API-KEY': '702efdffd42d58b1369eb20cc0951aca3ec8470b',
        'Content-Type': 'application/json'
    }

    async with aiohttp.ClientSession() as session:
        async with session.post(url, data=payload, headers=headers) as resp:
            data = await resp.text()
    return data

# %%
field_keyword_dict['Approval']
# Out:
# [['DLT approval guidelines', 'แนวทางการอนุมัติ DLT'],
#  ['DLT approval process Thailand', 'กระบวนการอนุมัติ DLT ในประเทศไทย'],
#  ['DLT approval requirements', 'ข้อกำหนดการอนุมัติ DLT'],
#  ['DLT approval updates', 'อัปเดตการอนุมัติ DLT'],
#  ['DLT certification Thailand', 'การรับรอง DLT ประเทศไทย']]

# %%
list(field_keyword_dict.keys())
# Out:
# ['Approval',
#  'Cert ',
#  'Certificate',
#  'Chemical regulation',
#  'Homologation',
#  'REACH',
#  'Type Approval',
#  'emmision',
#  'inspection']

# %%
async def main(field_keyword_dict, key):
    query_lis_en = [x[0] for x in field_keyword_dict[key]]
    query_tasks = [asyncio.create_task(get_google_result(query)) for query in query_lis_en]
    results = await asyncio.gather(*query_tasks)
    return key, results

# %%
res_dict = defaultdict(list)
for field in field_keyword_dict.keys():
    key, results = asyncio.run(main(field_keyword_dict, field))
    res_dict[key] = [eval(result) for result in results]
# Out:
# /Users/cuiyaodong/opt/miniconda3/envs/sgs_openai/lib/python3.11/asyncio/locks.py:168: RuntimeWarning: coroutine 'get_google_result' was never awaited
#   self._waiters = collections.deque()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
res_dict.keys()
# Out:
# dict_keys(['Approval', 'Cert ', 'Certificate', 'Chemical regulation', 'Homologation', 'REACH', 'Type Approval', 'emmision', 'inspection'])

# %%
res_dict['Approval']
# Out:
# [{'searchParameters': {'q': 'DLT approval guidelines',
#    'num': 20,
#    'type': 'search'},
#   'organic': [{'title': 'DLT Registration Process & Guidelines | DLT verified entity approved by TRAI',
#     'link': 'https://www.mysmsmantra.com/dlt-registration.html',
#     'snippet': 'Step 1: Entity/ Enterprise Registration; Step 2: Header (Sender ID) Registration; Step 3: Consent Template Registration; Step 4: Content Template Registration.',
#     'position': 1},
#    {'title': 'A Step by Step Guide to DLT Registration in India for sending SMS - EnableX.io',
#     'link': 'https://www.enablex.io/insights/a-step-by-step-guide-to-dlt-registration/',
#     'snippet': 'Learn how you can apply for DLT registration to send SMS to customers. DLT Registration is mandatory to send SMS as a Business in India.',
#     'date': 'Jan 23, 2023',
#     'position': 2},
#    {'title': 'Is DLT Registration mandatory? Exploring the complete TRAI guidelines - Medium',
#     'link': 'https://medium.com/@spaceedge.seo/is-dlt-registration-mandatory-exploring-the-complete-trai-guidelines-49a4e80ee198',
#     'snippet': 'As per TRAI regulations, every Principal Entity (PE) is required to register its consent template on the DLT platform before sending bulk SMS.',
#     'date': 'Jul 5, 2023',
#     'position': 3},
#    {'title': 'DLT registration process and FAQs - CEE',
#     'link': 'https://cedocs.netcorecloud.com/docs/dlt-faqs',
#     'snippet': 'Yes, DLT registration is mandatory as per the latest TRAI regulations. Every company/organization has to register on the DLT platform to continue sending SMS to ...',
#     'position': 4},
#    {'title': 'DLT Registration: Process, Approval for SMS & TRAI Guidelines? - Corpseed',
#     'link': 'https://www.corpseed.com/knowledge-centre/dlt-registration',
#     'snippet': 'All entities must now register on the Distributed Ledger Technology (DLT) platform according to a requirement from the Telecom Regulatory ...',
#     'date': 'Jul 13, 2022',
#     'position': 5},
#    {'title': 'Detailed guide on DLT registration for SMS in India - Plivo',
#     'link': 'https://www.plivo.com/blog/dlt-registration/',
#     'snippet': 'How to Complete DLT Registration for Sending Text Messages in India · 1. Get a unique Entity ID · 2. Register headers · 3. Register consent ...',
#     'date': 'Sep 9, 2022',
#     'position': 6},
#    {'title': 'DLT registration procedure and documents list - Lucep',
#     'link': 'https://lucep.com/blog/dlt-registration',
#     'snippet': 'The two key documents you will need for registering as a Principal Entity on any of the above platforms is your Business PAN Card and a proof of ...',
#     'date': 'Apr 28, 2022',
#     'position': 7},
#    {'title': 'DLT Registration Process for Sending SMS to India - Plivo support',
#     'link': 'https://support.plivo.com/hc/en-us/articles/360046769131-DLT-Registration-Process-for-Sending-SMS-to-India',
#     'snippet': 'DLT Registration Process for Sending SMS to India · Step 1 — Get unique Entity ID · Step 2 — Register headers · Step 3 — Register consent templates.',
#     'date': 'Apr 4, 2023',
#     'position': 8},
#    {'title': 'What is DLT and How to register on DLT platform? - uEngage',
#     'link': 'https://www.uengage.in/spotlight/how-to-register-on-dlt-platform',
#     'snippet': 'How to register on the DLT platform? · Sign-up by choosing as an enterprise · Enter your Business PAN details · Enter the email address and password you would use ...',
#     'position': 9},
#    {'title': 'DLT Registration Process for Sending SMS | OTP Verification - miniOrange',
#     'link': 'https://plugins.miniorange.com/dlt-registration-process-for-sending-sms',
#     'snippet': 'DLT stands for Distributed Ledger Technology. DLT Registration is neccessary for sending SMS to curb unsolicited commercial communication.',
#     'position': 10},
#    {'title': 'TRAI DLT Regulations (India) - WebEngage Docs',
#     'link': 'https://docs.webengage.com/docs/trai-sms-dlt-regulations-india',
#     'snippet': 'TRAI has deemed it mandatory for all SMS marketers to provide their PE ID (w.e.f Nov 1, 2020) and DLT Template ID (w.e.f Feb 1, 2021) in the message payload for ...',
#     'position': 11},
#    {'title': 'How To Do DLT Registration? - Read Complete Process - Fast2SMS',
#     'link': 'https://www.fast2sms.com/DLT-Registration',
#     'snippet': 'DLT Registration Process · 1. Register your Business Entity in the DLT portal. Click here to understand the step by step process of DLT registration in Jio. · 2.',
#     'position': 12},
#    {'title': 'TRAI TCCCPR 2018 | DLT Registration Process & Guidelines | Textlocal India',
#     'link': 'https://www.textlocal.in/tcccpr-trai-dlt-registration/',
#     'snippet': 'Register on any DLT platforms below by filling in the required information and document. After receiving Entity ID/Registration ID, please add it to your ...',
#     'position': 13},
#    {'title': 'How to Register Content Templates on DLT | DLT Template Registration Process - SMSCountry',
#     'link': 'https://www.smscountry.com/blog/dlt-template-registration-guide/',
#     'snippet': 'How to create a DLT template · Consent registration: This is the process of collecting the consent of the end consumer to forward any future communications to ...',
#     'position': 14},
#    {'title': '[PDF] Guidelines - | European Securities and Markets Authority',
#     'link': 'https://www.esma.europa.eu/sites/default/files/library/ESMA70-460-213_DLTR_GLs_on_application_standard_forms_formats_templates.pdf',
#     'snippet': 'Guidelines. On standard forms, formats and templates to apply for permission to operate a DLT market infrastructure ...',
#     'date': 'Mar 8, 2023',
#     'position': 15},
#    {'title': 'Airtel DLT Registration - How To Get Approved on First Attempt - SMSCountry',
#     'link': 'https://www.smscountry.com/blog/airtel-dlt-registration/',
#     'snippet': 'Airtel DLT registration is the process of uploading your business data to the DLT database. Airtel, which is a telecommunications operator, can approve or ...',
#     'position': 16},
#    {'title': 'Content Template Guideline on DLT | TRAI Rules For BULK SMS 2020 | Bulksmsplans.com',
#     'link': 'https://www.bulksmsplans.com/content-template-guideline-on-dlt',
#     'snippet': 'So Here Are Some Content Template Guideline on DLT · Consent Template: Standard message that is sent to consumers seeking their consent to receive promotional/ ...',
#     'position': 17},
#    {'title': '[PDF] Registration on DLT portal Part – How to apply for TRAI Exemption - Mobile Seva',
#     'link': 'https://mgov.gov.in/Resources/SMS_DLT_reg.pdf',
#     'snippet': 'the details of CDAC documentation & DLT Registration process. Department has to follow further steps to register on DLT portal ...',
#     'position': 18},
#    {'title': 'SMS Registration and DLT Compliance | Fynd Platform Help Center',
#     'link': 'https://platform.fynd.com/help/docs/miscellaneous/dlt-compliance/',
#     'snippet': 'SMS template - DLT guidelines\u200b · Brand name is mandatory for OTP and all Service messages. · Do not exceed the 180 characters limit (including variable and fixed ...',
#     'position': 19},
#    {'title': 'DLT Registration Process step by step Guidelines | Authkey.io',
#     'link': 'https://authkey.io/dlt-registration',
#     'snippet': 'TRAI DLT Registration. Distributed Ledger Technology (DLT) is a block-chain based registration system. Register your Business Principle Entity ID to send SMS in ...',
#     'position': 20}],
#   'peopleAlsoAsk': [{'question': 'What is DLT approved?',
#     'snippet': 'Distributed Ledger Technology (DLT) is a block-chain based registration system.\nIt is implemented in the public interest to control the SMS spam. whoever wants\nto send promotional bulk sms or transactional SMS to their customers needs to be\nDLT registered.',
#     'title': 'DLT Registration Process & Guidelines | DLT verified entity approved by TRAI',
#     'link': 'https://www.mysmsmantra.com/dlt-registration.html'},
#    {'question': 'What is required for DLT?',
#     'snippet': 'DLT registration is a mandatory requirement set by the Telecom Regulatory\nAuthority of India (TRAI) and must be complied with by any organization that\nwants to send SMS messages in India.\nJan 23, 2023',
#     'title': 'A Step by Step Guide to DLT Registration in India for sending SMS - EnableX.io',
#     'link': 'https://www.enablex.io/insights/a-step-by-step-guide-to-dlt-registration/'},
#    {'question': 'How do I approve a DLT template?',
#     'snippet': 'Login to the portal with your credentials. Go to the consent template section,\nprovide the details, and upload the consent template and save. Wait till it gets\napproved by the DLT registrar.',
#     'title': 'Dlt Template Registration Process | DLT & UCC Guidelines for SMS',
#     'link': 'https://www.smsgatewayhub.com/dlt-template-registration-process.aspx'},
#    {'question': 'How long does it take for DLT template to be approved?',
#     'snippet': 'Due to a large number of requests you may face some delay in approval, however,\na minimum of 2-4 business days wait is expected.',
#     'title': 'DLT Content Template FAQs - MSG91',
#     'link': 'https://msg91.com/help/MSG91/dlt-content-template-faqs'}],
#   'relatedSearches': [{'query': 'TRAI DLT registration'},
#    {'query': 'DLT Registration charges'},
#    {'query': 'DLT registration validity'},
#    {'query': 'Documents required for DLT registration'},
#    {'query': 'DLT registration for individual'},
#    {'query': 'DLT full form SMS'},
#    {'query': 'Airtel DLT registration'},
#    {'query': 'DLT registration Jio'}]},
#  {'searchParameters': {'q': 'DLT approval process Thailand',
#    'num': 20,
#    'type': 'search'},
#   'organic': [{'title': 'Thai DLT Certification - Qman Consulting',
#     'link': 'http://www.qman-consulting.com/thai-dlt.html',
#     'snippet': 'In Thailand, new motor vehicles must be approved by Local The Department of Land Transport (DLT) Offices for initial inspection and registration before they can ...',
#     'position': 1},
#    {'title': 'Driving in Thailand - U.S. Embassy & Consulate in Thailand',
#     'link': 'https://th.usembassy.gov/u-s-citizen-services/local-resources-of-u-s-citizens/driving-in-thailand/',
#     'snippet': 'Please note, International driving license is valid for 1 year. For more information, please visit https://www.dlt.go.th/en/international-driving-licence/ ...',
#     'position': 2},
#    {'title': 'Thailand drivers license',
#     'link': 'https://www.thailandguru.com/thailand-drivers-license.html',
#     'snippet': 'In Bangkok, the office is located opposite Chatuchak Park, by the Mo Chit bus station, at 1032 Phahonyothin Rd. Application can also be made at the Vehicle ...',
#     'position': 3},
#    {'title': "How to get a Driver's License in Thailand as an Expat - Shelter",
#     'link': 'https://shelter.global/how-to-get-a-drivers-license-in-thailand-as-an-expat/',
#     'snippet': "To obtain a driver's license in Thailand, you must attend a driving school approved by the Department of Land Transport (DLT).",
#     'date': 'Mar 9, 2023',
#     'position': 4},
#    {'title': 'Thailand Motor Vehicle Type Approval - ATIC',
#     'link': 'https://www.atic-ts.com/thailand-motor-vehicle-type-approval/',
#     'snippet': 'Motor vehicle type approval procedure in Thailand includes Safety Certification and ... which are respectively responsible and supervised by DLT and TISI.',
#     'position': 5},
#    {'title': "[Thailand] How to obtain a driving license? Getting a driver's license for foreigners",
#     'link': 'https://asiabusinessassembly.com/en/drivers-license-for-foreigners/',
#     'snippet': 'You can renew to a 5-year driving license. Required documents. (1) Passport with non-immigrant VISA (Original and a certified copy) (2) Original ...',
#     'date': 'Mar 27, 2023',
#     'position': 6},
#    {'title': 'How to Get a Thai Driving License: Documents, Test and Renewal - ExpatDen',
#     'link': 'https://www.expatden.com/thailand/thai-driving-license/',
#     'snippet': "But for this guide, we'll focus on the process at the DLT in Chatuchak, as it's the most popular place for expats to get a Thai driving license.",
#     'date': 'Jun 21, 2023',
#     'position': 7},
#    {'title': 'How to Get a Driving License in Thailand - YouTube',
#     'link': 'https://youtube.com/watch?v=vVdofoeS9WU',
#     'snippet': 'For the department of land and transport website go here ...',
#     'date': 'Jul 2, 2022',
#     'attributes': {'Duration': '32:02', 'Posted': 'Jul 2, 2022'},
#     'imageUrl': 'https://i.ytimg.com/vi/vVdofoeS9WU/default.jpg?sqp=-oaymwEECHgQQw&rs=AMzJL3lY2FxadDHQ-12_KzrtdQE_k3R6LA',
#     'position': 8},
#    {'title': 'NBTC and DLT Certificated GPS tracker for Thailand Market - LinkedIn',
#     'link': 'https://www.linkedin.com/pulse/nbtc-dlt-certificated-gps-tracker-thailand-market-concox-gps',
#     'snippet': '... tracker is approved by the NBTC and DLT successfully. What is the NBTC & DLT certification? NBTC is a wireless certification in Thailand.',
#     'date': 'Mar 4, 2020',
#     'position': 9},
#    {'title': 'DLT Thai Licence Online App - English Language Instructions. (Only valid for newer licences with QR Code on the back) For those struggling with... | By Zed CM | Facebook',
#     'link': 'https://facebook.com/motogirlthailand/videos/dlt-thai-licence-online-app-english-language-instructions/752008621892795/',
#     'snippet': 'application with instructions in English. I hope it helps ...',
#     'date': 'Oct 28, 2019',
#     'attributes': {'Duration': '2:06', 'Posted': 'Oct 28, 2019'},
#     'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTy0Y3AMmPFE_uGzwPFaSS74KO-gclTlqteg44Snf5JEwYMH27qJRNmow',
#     'position': 10},
#    {'title': 'Thai SEC Approves DLT for Securities Trading - SuperCryptoNews',
#     'link': 'https://www.supercryptonews.com/thai-sec-approves-dlt-for-securities-trading/',
#     'snippet': "Thailand's Securities and Exchange Commission has given approval to the ... Distributed Ledger Technology (DLT) in its regulatory sandbox to ...",
#     'date': 'Dec 15, 2019',
#     'position': 11},
#    {'title': 'How to get the blue book translation from DLT? - Thailand Motor Discussion - ASEAN NOW',
#     'link': 'https://aseannow.com/topic/962401-how-to-get-the-blue-book-translation-from-dlt/',
#     'snippet': 'I am planning to go to Malaysia and cross the border in Satun province (wang prachan) in about 2 weeks with my car which is registered in SURIN ...',
#     'date': 'Jan 7, 2017',
#     'position': 12},
#    {'title': 'Starting a Container Trucking Company in Thailand - Haulio',
#     'link': 'https://www.haulio.io/en-th/blog/starting-container-trucking-thailand/',
#     'snippet': 'Furthermore, the GPS system must come from a vendor that is pre-approved by the DLT. For prime movers/trucks going in and out of the respective ports in ...',
#     'position': 13},
#    {'title': 'Impossible to login to DLT Smart Queue Application with passport ID - ASEAN NOW',
#     'link': 'https://aseannow.com/topic/1230898-impossible-to-login-to-dlt-smart-queue-application-with-passport-id/',
#     'snippet': 'when I got to Land Transportation at Banglamung I was told in no uncertain terms it was for THAI only....I had to get a ticket and wait with the ...',
#     'date': 'Sep 9, 2021',
#     'position': 14},
#    {'title': 'Medical Device and IVD Registration and Approval in Thailand | Emergo by UL',
#     'link': 'https://www.emergobyul.com/services/medical-device-and-ivd-registration-and-approval-thailand',
#     'snippet': "Let Emergo assist you with Thailand's regulatory approval process · We can assist you in properly classifying your device to streamline the registration process.",
#     'attributes': {'Missing': 'DLT | Show results with:DLT'},
#     'position': 15},
#    {'title': 'DLT confirms Bolt as legitimate taxi app in Thailand - The Phuket News',
#     'link': 'https://www.thephuketnews.com/dlt-confirms-bolt-as-legitimate-taxi-app-in-thailand-88395.php',
#     'snippet': 'While they primarily serve designated locations such as hotels or shopping malls, customers can order these taxis through approved mobile ...',
#     'date': 'Jun 4, 2023',
#     'position': 16},
#    {'title': 'Vehicle registration plates of Thailand - Wikipedia',
#     'link': 'https://en.wikipedia.org/wiki/Vehicle_registration_plates_of_Thailand',
#     'snippet': "Thailand's vehicle registration plates are issued by the Department of Land Transport (DLT) ... The plates vary in design, colors and dimensions according to the type of ...",
#     'position': 17},
#    {'title': 'Thailand Regulating Ride-Hailing Service Business | ZICO Law',
#     'link': 'https://www.zicolaw.com/resources/alerts/thailand-regulating-ride-hailing-service-business/',
#     'snippet': 'In mid 2021, the Ministry of Transport of Thailand issued the Ministerial ... systems are required to be approved and verified by the DLT.',
#     'date': 'Feb 21, 2022',
#     'position': 18},
#    {'title': 'Another double standard to come: The legalisation of ride-hailing in Thailand - LSE Blogs',
#     'link': 'https://blogs.lse.ac.uk/seac/2023/02/23/another-double-standard-to-come-the-legalisation-of-ride-hailing-in-thailand/',
#     'snippet': 'For countries in Southeast Asia like Thailand, Indonesia, ... is only for Taxis and requires all platforms to seek approval from the DLT.',
#     'date': 'Feb 23, 2023',
#     'position': 19},
#    {'title': '[PDF] Doing Business in Thailand - Baker McKenzie',
#     'link': 'https://www.bakermckenzie.com/en/insight/publications/guides/-/media/files/insight/guides/2021/doing-business-in-thailand-2021_260421.pdf',
#     'snippet': 'Additionally, summaries of various aspects of. Thai law that generally affect most business operations in Thailand are included for the ...',
#     'date': 'Apr 19, 2020',
#     'position': 20}],
#   'peopleAlsoAsk': [{'question': 'Can I drive in Thailand with a USA license?',
#     'snippet': 'According to the UN Traffic Act of 1949 and the Thai Traffic Act of 1979, an IDP\nis not required if you are a tourist/visitor in Thailand as long as your license\nis in English, has a photo, and your country is a contracting state of the 1949\ntreaty, which most are.',
#     'title': 'Inside Thailand : Driving - License Requirements - Tripadvisor',
#     'link': 'https://www.tripadvisor.com/Travel-g293915-c133830/Thailand:Driving.License.Requirements.html'},
#    {'question': 'What is vehicle type approval in Thailand?',
#     'snippet': 'Motor vehicle type approval procedure in Thailand includes Safety Certification\nand Emission Certification, which are respectively responsible and supervised by\nDLT and TISI. In addition, the on-board wireless communication system and radar\nsystems are supervised by the Office of the National Broadcasting and ...',
#     'title': 'Thailand Motor Vehicle Type Approval - ATIC',
#     'link': 'https://www.atic-ts.com/thailand-motor-vehicle-type-approval/'},
#    {'question': 'What license do I need to drive in Thailand?',
#     'snippet': "An international driving license is accepted as long as it is valid, but a\nforeign license is not accepted in Thailand. If you are a resident and eligible,\nyou should obtain a Thai Driver's License.",
#     'title': 'Driving in Thailand - U.S. Embassy & Consulate in Thailand',
#     'link': 'https://th.usembassy.gov/u-s-citizen-services/local-resources-of-u-s-citizens/driving-in-thailand/'}],
#   'relatedSearches': [{'query': 'Can tourist drive in Thailand'},
#    {'query': 'International motorbike license Thailand'},
#    {'query': 'Is IDP valid in Thailand'},
#    {'query': 'IDP 1968 Thailand'},
#    {'query': 'How to get International driving license'},
#    {'query': 'Do you need a motorcycle license in Thailand'},
#    {'query': 'International driving permit UK'},
#    {'query': 'International driving license India'}]},
#  {'searchParameters': {'q': 'DLT approval requirements',
#    'num': 20,
#    'type': 'search'},
#   'answerBox': {'snippet': 'Required Documentation for the DLT registration:\n * Proof of Identity – PAN Card (Business PAN card)\n * Proof of Address – GST Certificate, Certificate of Incorporation, TAN\n   Certificate, FSSAI License, Import/Export Registration Certificate.\n * Letter of Authorization.',
#    'snippetHighlighted': ['Required Documentation for the DLT registration:'],
#    'title': 'What is DLT and How to register on DLT platform? - uEngage',
#    'link': 'https://www.uengage.in/spotlight/how-to-register-on-dlt-platform'},
#   'organic': [{'title': 'DLT Registration Process & Guidelines | DLT verified entity approved by TRAI',
#     'link': 'https://www.mysmsmantra.com/dlt-registration.html',
#     'snippet': 'Step 1: Entity/ Enterprise Registration; Step 2: Header (Sender ID) Registration; Step 3: Consent Template Registration; Step 4: Content Template Registration.',
#     'position': 1},
#    {'title': 'A Step by Step Guide to DLT Registration in India for sending SMS - EnableX.io',
#     'link': 'https://www.enablex.io/insights/a-step-by-step-guide-to-dlt-registration/',
#     'snippet': 'DLT registration is a mandatory requirement set by the Telecom Regulatory Authority of India (TRAI) and must be complied with by any ...',
#     'date': 'Jan 23, 2023',
#     'position': 2},
#    {'title': 'DLT registration procedure and documents list - Lucep',
#     'link': 'https://lucep.com/blog/dlt-registration',
#     'snippet': 'The two key documents you will need for registering as a Principal Entity on any of the above platforms is your Business PAN Card and a proof of ...',
#     'date': 'Apr 28, 2022',
#     'position': 3},
#    {'title': 'DLT registration process and FAQs - CEE',
#     'link': 'https://cedocs.netcorecloud.com/docs/dlt-faqs',
#     'snippet': 'Yes, DLT registration is mandatory as per the latest TRAI regulations. Every company/organization has to register on the DLT platform to continue sending SMS to ...',
#     'position': 4},
#    {'title': 'Documents Required for DLT Registration - Complete List [Updated] - DomainAdda',
#     'link': 'https://www.domainadda.com/blog/documents-required-for-dlt-registration/',
#     'snippet': 'Documents Required for DLT Registration · Company PAN/TAN Card with Soft Copy · Company GST (Soft Copy) · Proof of Authorized Signatory · Proof of ...',
#     'date': 'Oct 13, 2021',
#     'position': 5},
#    {'title': 'Detailed guide on DLT registration for SMS in India - Plivo',
#     'link': 'https://www.plivo.com/blog/dlt-registration/',
#     'snippet': 'DLT registration: Distributed ledger technology (DLT) platform registration is mandatory for sending bulk messaging in India.',
#     'date': 'Sep 9, 2022',
#     'position': 6},
#    {'title': 'Is DLT Registration mandatory? Exploring the complete TRAI guidelines - Medium',
#     'link': 'https://medium.com/@spaceedge.seo/is-dlt-registration-mandatory-exploring-the-complete-trai-guidelines-49a4e80ee198',
#     'snippet': 'Documents required for DLT registration. 1. Company PAN Card Copy. 2. Company GST. 3. Letter of authorization.',
#     'date': 'Jul 5, 2023',
#     'position': 7},
#    {'title': 'DLT Registration Process for Sending SMS to India - Plivo support',
#     'link': 'https://support.plivo.com/hc/en-us/articles/360046769131-DLT-Registration-Process-for-Sending-SMS-to-India',
#     'snippet': 'Step 1 — Get unique Entity ID. Register on any of the DLT platforms below by filling in the required information to get a temporary ID. After ...',
#     'date': 'Apr 4, 2023',
#     'position': 8},
#    {'title': 'DLT Registration: Process, Approval for SMS & TRAI Guidelines? - Corpseed',
#     'link': 'https://www.corpseed.com/knowledge-centre/dlt-registration',
#     'snippet': 'All entities must now register on the Distributed Ledger Technology (DLT) platform according to a requirement from the Telecom Regulatory ...',
#     'date': 'Jul 13, 2022',
#     'position': 9},
#    {'title': 'Airtel DLT Registration - How To Get Approved on First Attempt - SMSCountry',
#     'link': 'https://www.smscountry.com/blog/airtel-dlt-registration/',
#     'snippet': 'Get FREE SMS credits when you Sign up on SMSCOUNTRY. No credit card required. You can watch this tutorial video that goes through the process from beginning to ...',
#     'position': 10},
#    {'title': 'What is DLT Registration? Why It Is Required For SMS Service In India? - Corefactors',
#     'link': 'https://www.corefactors.in/blog/what-is-dlt-registration/',
#     'snippet': 'Enterprise Registration Process · Choose as an Enterprise. · Click on “No” when asked “Have you registered with any other mobile operator DLT ...',
#     'date': 'Jun 20, 2022',
#     'position': 11},
#    {'title': 'What is DLT Template and its purpose? How to get approval for it? - MyOperator',
#     'link': 'https://myoperator.com/blog/what-is-dlt-template',
#     'snippet': 'Getting approval for a DLT Template can vary depending on the telecom operator and the specific requirements in your country.',
#     'position': 12},
#    {'title': 'DLT Registration Process for Sending SMS | OTP Verification - miniOrange',
#     'link': 'https://plugins.miniorange.com/dlt-registration-process-for-sending-sms',
#     'snippet': '1. How to register Sender ID · Register on any of the DLT platforms below by filling in the required information to get a temporary ID: · After verification of ...',
#     'position': 13},
#    {'title': 'DLT Registration Process step by step Guidelines | Authkey.io',
#     'link': 'https://authkey.io/dlt-registration',
#     'snippet': 'TRAI DLT Registration. Distributed Ledger Technology (DLT) is a block-chain based registration system. Register your Business Principle Entity ID to send SMS in ...',
#     'position': 14},
#    {'title': 'How To Do DLT Registration? - Read Complete Process - Fast2SMS',
#     'link': 'https://www.fast2sms.com/DLT-Registration',
#     'snippet': 'DLT Registration Process · 1. Register your Business Entity in the DLT portal. Click here to understand the step by step process of DLT registration in Jio. · 2.',
#     'position': 15},
#    {'title': 'DLT Registration Process & Guidelines for Sending SMS to India - smsindiahub',
#     'link': 'https://www.smsindiahub.in/dlt-registration-now-a-mandate/',
#     'snippet': 'DLT Registration Process for Entity and Telemarketer · Business PAN Number with Soft Copy. · GST Number (GST Certificate) · Business Established Certificate.',
#     'position': 16},
#    {'title': '5 Mistakes that cause DLT Registration rejection (+ 5 things to do) - SMSCountry',
#     'link': 'https://www.smscountry.com/blog/reasons-for-dlt-registration-rejection/',
#     'snippet': "The registration process for DLT requires a business to produce all the required documents such as PAN card, your business' GST, and consent letters.",
#     'position': 17},
#    {'title': 'TRAI TCCCPR 2018 | DLT Registration Process & Guidelines | Textlocal India',
#     'link': 'https://www.textlocal.in/tcccpr-trai-dlt-registration/',
#     'snippet': 'Register on any DLT platforms below by filling in the required information and document. After receiving Entity ID/Registration ID, please add it to your ...',
#     'position': 18},
#    {'title': 'Everything you need to know on SMS / Texting – DLT and Template approval in India',
#     'link': 'https://www.helloleads.io/blog/all/marketing-and-sales/everything-you-need-to-know-on-sms-texting-dlt-and-template-approval-in-india/',
#     'snippet': 'The first step to get a DLT approval is to register (as an entity or as a telemarketer) on any one of the DLT platforms (i.e., service providers) by filling in ...',
#     'position': 19}],
#   'peopleAlsoAsk': [{'question': 'What is consent in DLT?',
#     'snippet': "Definition. It is for receiving the customer's permission before sending\npromotional SMS. It is the message text that has to be submitted on the DLT\nplatform.",
#     'title': 'Difference between Consent and Content Templates in DLT',
#     'link': 'https://www.fast2sms.com/help/difference-consent-content-templates-dlt/'},
#    {'question': 'What is required for DLT?',
#     'snippet': 'DLT registration is a mandatory requirement set by the Telecom Regulatory\nAuthority of India (TRAI) and must be complied with by any organization that\nwants to send SMS messages in India.\nJan 23, 2023',
#     'title': 'A Step by Step Guide to DLT Registration in India for sending SMS - EnableX.io',
#     'link': 'https://www.enablex.io/insights/a-step-by-step-guide-to-dlt-registration/'},
#    {'question': 'How long does it take for DLT content template to be approved?',
#     'snippet': 'How much time does it takes to get the approval of the Content Template from the\nDLT platform? Due to a large number of requests you may face some delay in\napproval, however, a minimum of 2-4 business days wait is expected.',
#     'title': 'DLT Content Template FAQs - MSG91',
#     'link': 'https://msg91.com/help/MSG91/dlt-content-template-faqs'},
#    {'question': 'How do I approve DLT?',
#     'snippet': 'DLT REGISTRATION PROCESS\n1\nRegister your Business Entity in the DLT portal. Click here to understand the\nstep by step process of DLT registration in Jio.\n2\nNext step is to add Telemarketer in your registered DLT portal. ...\n3\nSubmit Sender ID and get it approved. ...\n4\nSubmit Content Template (message text) and get it approved.',
#     'title': 'How To Do DLT Registration? - Read Complete Process - Fast2SMS',
#     'link': 'https://www.fast2sms.com/DLT-Registration'}],
#   'relatedSearches': [{'query': 'DLT registration for individual'},
#    {'query': 'Jio DLT registration'},
#    {'query': 'TRAI DLT registration'},
#    {'query': 'DLT registration validity'},
#    {'query': 'DLT registration free'},
#    {'query': 'BSNL DLT registration fees'},
#    {'query': 'Jio DLT registration charges'},
#    {'query': 'DLT SMS full form'}]},
#  {'searchParameters': {'q': 'DLT approval updates',
#    'num': 20,
#    'type': 'search'},
#   'organic': [{'title': 'Simplified Onboarding for DLT-Registered Messaging in India - Plivo',
#     'link': 'https://www.plivo.com/changelog/announcements/simplified-onboarding-for-dlt-registered-messaging-in-india',
#     'snippet': 'With this update, we have simplified the onboarding process for India-focused users by eliminating the need for template whitelisting. Now, ...',
#     'date': 'Aug 1, 2023',
#     'position': 1},
#    {'title': 'DLT Registration Process for Sending SMS to India - Plivo support',
#     'link': 'https://support.plivo.com/hc/en-us/articles/360046769131-DLT-Registration-Process-for-Sending-SMS-to-India',
#     'snippet': 'We will send you updates, transactions, recommendations of our services and products to our registered customers. Dos for consent templates.',
#     'date': 'Apr 4, 2023',
#     'position': 2},
#    {'title': 'India DLT Update - Support',
#     'link': 'https://support.telesign.com/s/article/India-DLT-Update',
#     'snippet': 'DLT ID: Each Indian entity will receive their own DLT ID once its registration is approved by the carriers. Headers (Sender IDs): These are DLT- ...',
#     'date': 'May 26, 2023',
#     'position': 3},
#    {'title': 'Approval DLT - Messaging - Kaleyra',
#     'link': 'https://messaging.kaleyra.com/support/solutions/articles/3000101071-what-if-i-am-not-receiving-any-update-from-the-operator-even-after-multiple-followups-on-dlt-',
#     'snippet': 'Please reach out to your account manager with the below details so that we can get this expedited for you. Registered Email ID; Registered Phone ...',
#     'date': 'Jul 9, 2020',
#     'position': 4},
#    {'title': 'DLT registration process and FAQs - CEE',
#     'link': 'https://cedocs.netcorecloud.com/docs/dlt-faqs',
#     'snippet': 'Registration approval might take 3-5 working days. You will receive notification regarding approval or rejection of the DLT Entity on your registered email ID.',
#     'position': 5},
#    {'title': 'Channel Partners | DLT Solutions, a Tech Data company',
#     'link': 'https://www.dlt.com/services/channel-partners',
#     'snippet': 'If you are seeking credit in excess of $500K, the approval process may be a little longer. ... or for periodical updates to your account information.',
#     'position': 6},
#    {'title': 'DLT : Content template updating and Scrubbing - SMS-Magic Messaging Guides',
#     'link': 'https://www.sms-magic.com/docs/messaging-guides/knowledge-base/content-template-updating-and-scrubbing/',
#     'snippet': 'The regulatory process of scrubbing the Entity ID, Sender IDs, and Template would be enabled with all Operators effective 7th January, 2021. As ...',
#     'date': 'Dec 14, 2020',
#     'position': 7},
#    {'title': 'DLT Registration Process for Sending SMS | OTP Verification - miniOrange',
#     'link': 'https://plugins.miniorange.com/dlt-registration-process-for-sending-sms',
#     'snippet': 'DLT stands for Distributed Ledger Technology. DLT Registration is neccessary for sending SMS to curb unsolicited commercial communication.',
#     'position': 8},
#    {'title': 'DLT Registration Process & Guidelines | DLT verified entity approved by TRAI',
#     'link': 'https://www.mysmsmantra.com/dlt-registration.html',
#     'snippet': 'DLT Guideline Update as on October 11, 2020 ... Please note: If the account & Header is approved from anyone DLT platform it gets sync with all operators.',
#     'position': 9},
#    {'title': 'Still are you facing problem in Sending SMS or DLT Registration ? - LinkedIn',
#     'link': 'https://www.linkedin.com/pulse/still-you-facing-problem-sending-sms-dlt-registration-rahul-jain',
#     'snippet': 'Step 3 – Additional Steps for BSNL DLT & VILPOWER DLT Only · Please reach out to us with your Unique ID if your KYC documents have been approved ...',
#     'date': 'Jun 26, 2020',
#     'position': 10},
#    {'title': 'Get Approval for your SMS Content on DLT Platform - MSG91',
#     'link': 'https://msg91.com/help/MSG91/get-approval-for-your-sms-content-on-dlt-platform',
#     'snippet': 'Get Approval for your SMS Content on DLT Platform SMS Content Template Registration is the next process for DLT and as per the Telecom Regulatory Authority.',
#     'position': 11},
#    {'title': 'Airtel DLT Registration - How To Get Approved on First Attempt - SMSCountry',
#     'link': 'https://www.smscountry.com/blog/airtel-dlt-registration/',
#     'snippet': 'In other words, DLT \u200b\u200bis a shared database that is available across a network of computers. There are different uses of DLT. In this case, TRAI uses DLT to ...',
#     'position': 12},
#    {'title': 'How to Register Content Templates on DLT | DLT Template Registration Process - SMSCountry',
#     'link': 'https://www.smscountry.com/blog/dlt-template-registration-guide/',
#     'snippet': 'Usually, it takes 2-4 business days for approval. But you can expect approval delays if many requests are in the queue. What is a template in bulk SMS? A ...',
#     'position': 13},
#    {'title': 'TRAI TCCCPR 2018 | DLT Registration Process & Guidelines | Textlocal India',
#     'link': 'https://www.textlocal.in/tcccpr-trai-dlt-registration/',
#     'snippet': 'Textlocal checks your messages against all your approved templates and passes the message with the associated DLT template ID only if it is an exact match with ...',
#     'position': 14},
#    {'title': 'How to add DLT approved templates on SMS Alert - YouTube',
#     'link': 'https://youtube.com/watch?v=RYQf-3X5oaw',
#     'snippet': 'How to add DLT templates to SMS Alert? After your ...',
#     'date': 'Aug 6, 2021',
#     'attributes': {'Duration': '2:11', 'Posted': 'Aug 6, 2021'},
#     'imageUrl': 'https://i.ytimg.com/vi/RYQf-3X5oaw/default.jpg?sqp=-oaymwEECHgQQw&rs=AMzJL3k4jWuO_vYCBPHiNyBcnTUpDyuRfA',
#     'position': 15},
#    {'title': 'Complete DLT Entity Registration | Header Approval on DLT Platform | Send Request to Telemarketer - YouTube',
#     'link': 'https://youtube.com/watch?v=pN87m9Arwok',
#     'snippet': 'Subscribe to stay updated with channel updates ...',
#     'date': 'Jun 25, 2020',
#     'attributes': {'Duration': '5:09', 'Posted': 'Jun 25, 2020'},
#     'imageUrl': 'https://i.ytimg.com/vi/pN87m9Arwok/default.jpg?sqp=-oaymwEECHgQQw&rs=AMzJL3kVb6rq8raUF3_D07iYbma53V3t_w',
#     'position': 16},
#    {'title': 'What is DLT Registration? Why It Is Required For SMS Service In India? - Corefactors',
#     'link': 'https://www.corefactors.in/blog/what-is-dlt-registration/',
#     'snippet': 'Telemarketer Registration Process · Choose as a Telemarketer. · Select the Aggregator function. · Click on “No” when asked “Have you registered ...',
#     'date': 'Jun 20, 2022',
#     'position': 17},
#    {'title': 'Everything you need to know on SMS / Texting – DLT and Template approval in India',
#     'link': 'https://www.helloleads.io/blog/all/marketing-and-sales/everything-you-need-to-know-on-sms-texting-dlt-and-template-approval-in-india/',
#     'snippet': 'The first step to get a DLT approval is to register (as an entity or as a telemarketer) on any one of the DLT platforms (i.e., service providers) by filling in ...',
#     'position': 18},
#    {'title': 'India SMS Features and Restrictions - Vonage API Support',
#     'link': 'https://api.support.vonage.com/hc/en-us/articles/204017423-India-SMS-Features-and-Restrictions',
#     'snippet': 'Important update & action required for Domestic DLT registered Customers · Re-Verify all your Headers (Sender ID) on the DLT platform that you ...',
#     'date': 'Aug 4, 2023',
#     'position': 19},
#    {'title': 'How to Pass DLT Template ID with the latest update for India - WordPress.org',
#     'link': 'https://wordpress.org/support/topic/how-to-pass-dlt-template-id-with-the-latest-update-for-india/',
#     'snippet': 'If we want custom notification then we need to create our own message template which to be approved by TRAI. The Telecom Regulatory Authority of India (TRAI) ...',
#     'position': 20}],
#   'peopleAlsoAsk': [{'question': 'How long does it take for DLT template to be approved?',
#     'snippet': 'Due to a large number of requests you may face some delay in approval, however,\na minimum of 2-4 business days wait is expected.',
#     'title': 'DLT Content Template FAQs - MSG91',
#     'link': 'https://msg91.com/help/MSG91/dlt-content-template-faqs'},
#    {'question': 'How do I check the status of my DLT registration?',
#     'snippet': 'For Videocon DLT platform only: You can check approval status of your\napplication, headers on Videcon DLT platform: Open\nhttps://smartping.live/entity/particular > Click on the option required and\nclick Next > Enter Entity Reference ID and click Submit > Insert OTP received on\nMobile and Click Submit > Pending Status > ...',
#     'title': 'TRAI TCCCPR 2018 | DLT Registration Process & Guidelines | Textlocal India',
#     'link': 'https://www.textlocal.in/tcccpr-trai-dlt-registration/'},
#    {'question': 'What is DLT approved?',
#     'snippet': 'Distributed Ledger Technology (DLT) is a block-chain based registration system.\nIt is implemented in the public interest to control the SMS spam. whoever wants\nto send promotional bulk sms or transactional SMS to their customers needs to be\nDLT registered.',
#     'title': 'DLT Registration Process & Guidelines | DLT verified entity approved by TRAI',
#     'link': 'https://www.mysmsmantra.com/dlt-registration.html'},
#    {'question': 'How do I approve a DLT template?',
#     'snippet': 'Login to the portal with your credentials. Go to the consent template section,\nprovide the details, and upload the consent template and save. Wait till it gets\napproved by the DLT registrar.',
#     'title': 'Dlt Template Registration Process | DLT & UCC Guidelines for SMS',
#     'link': 'https://www.smsgatewayhub.com/dlt-template-registration-process.aspx'}],
#   'relatedSearches': [{'query': 'DLT renewal'},
#    {'query': 'DLT full form in SMS'},
#    {'query': 'DLT connect'},
#    {'query': 'DLT Registration Fees'},
#    {'query': 'Free DLT Registration 2022'},
#    {'query': 'Jio DLT registration'},
#    {'query': 'Airtel DLT registration process'},
#    {'query': 'DLT registration validity'}]},
#  {'searchParameters': {'q': 'DLT certification Thailand',
#    'num': 20,
#    'type': 'search'},
#   'organic': [{'title': 'Thai DLT Certification - Qman Consulting',
#     'link': 'http://www.qman-consulting.com/thai-dlt.html',
#     'snippet': 'In Thailand, new motor vehicles must be approved by Local The Department of Land Transport (DLT) Offices for initial inspection and registration before they can ...',
#     'position': 1},
#    {'title': 'Temporary (Two Year) Driving License',
#     'link': 'https://www.dlt.go.th/en/two-year-license/',
#     'snippet': 'CHECK THE DOCUMENTS · PRINT THE APPLICATION FORM · TAKE ONLY A PHYSICAL TEST · PAY THE FEE / TAKE A PHOTO AND PRINT DRIVING LICENCE · * TAKE A TRAINING 1 HOURS · * ...',
#     'position': 2},
#    {'title': 'Thailand Motor Vehicle Type Approval - ATIC',
#     'link': 'https://www.atic-ts.com/thailand-motor-vehicle-type-approval/',
#     'snippet': '... procedure in Thailand includes Safety Certification and Emission Certification, which are respectively responsible and supervised by DLT and TISI.',
#     'position': 3},
#    {'title': 'NBTC and DLT Certificated GPS tracker for Thailand Market - LinkedIn',
#     'link': 'https://www.linkedin.com/pulse/nbtc-dlt-certificated-gps-tracker-thailand-market-concox-gps',
#     'snippet': 'The NBTC is classified as the certification of wireless WWAN/WLAN products. It is of great authority in Thailand. The wireless products approved ...',
#     'date': 'Mar 4, 2020',
#     'position': 4},
#    {'title': 'How to get a medical certificate for Thai driver´s license - cheap & fast',
#     'link': 'https://tdl-service.com/how-to-get-a-medical-certificate-for-thai-drivers-license/',
#     'snippet': 'The DLT requires a medical certificate for Thai Driver´s License. You can get the medical certificate at any clinic / hospital / doctor, just tell them it ...',
#     'position': 5},
#    {'title': "How to get a Driver's License in Thailand as an Expat - Shelter",
#     'link': 'https://shelter.global/how-to-get-a-drivers-license-in-thailand-as-an-expat/',
#     'snippet': "You can then visit the DLT office to obtain your official driver's license. The license is typically valid for two years and must be renewed ...",
#     'date': 'Mar 9, 2023',
#     'position': 6},
#    {'title': 'How to Get a Thai Driving License: Documents, Test and Renewal - ExpatDen',
#     'link': 'https://www.expatden.com/thailand/thai-driving-license/',
#     'snippet': 'An easy way to get a residence certificate in Thailand is to visit your local immigration office with your passport, a 90-day notification ...',
#     'date': 'Jun 21, 2023',
#     'position': 7},
#    {'title': 'DLT targets licence vendors - Bangkok Post',
#     'link': 'https://www.bangkokpost.com/thailand/general/2588269',
#     'snippet': 'He said applicants must submit their documents, such as a health certificate and the results of their driving test, at transportation offices or ...',
#     'date': 'Jun 9, 2023',
#     'position': 8},
#    {'title': "[PDF] Thailand's Electric Vehicle policies Department of Land Transport",
#     'link': 'https://www.jasic.org/meeting_docs_admin/contents/uploads/doc/meeting2/4-13%20DLT_Country%20report_2022.pdf',
#     'snippet': "Thailand's 20-year development strategy for transport systems (2018 -2037). Automotive ... Training for DLT and Private Inspector.",
#     'date': 'Nov 25, 2022',
#     'position': 9},
#    {'title': 'Driving in Thailand - U.S. Embassy & Consulate in Thailand',
#     'link': 'https://th.usembassy.gov/u-s-citizen-services/local-resources-of-u-s-citizens/driving-in-thailand/',
#     'snippet': 'Please note, International driving license is valid for 1 year. For more information, please visit https://www.dlt.go.th/en/international-driving-licence/ ...',
#     'position': 10},
#    {'title': 'Updated – How to get a Thai Driving License in Chonburi, Thailand? - juanderpaul life',
#     'link': 'https://juanderpaullife.com/2023/05/14/updated-how-to-get-a-thai-driving-license-in-chonburi-thailand/',
#     'snippet': 'For foreigners, before you go to the Department of Land Transport (DLT), you need to secure the following documentary requirements: You can get ...',
#     'date': 'May 14, 2023',
#     'position': 11},
#    {'title': "5 Steps to Prepare for Online Driver's License Renewal - AXA",
#     'link': 'https://www.axa.co.th/en/5-Steps-to-Prepare-for-Online-Driver-License-Renewal',
#     'snippet': "Training lesson required for Thai driver's license is now online. The e-learning lesson is available on www.dlt-elearning.com, which supports smartphones, ...",
#     'position': 12},
#    {'title': 'Walk-in driving license services now available in Thailand - Thaiger',
#     'link': 'https://thethaiger.com/news/national/walk-in-driving-license-services-now-available-in-thailand',
#     'snippet': "Anyone wanting to renew their Thai driving license can obtain an 'eLearning' theoretical training certificate through the DLT's website, ...",
#     'date': 'Jan 19, 2023',
#     'position': 13},
#    {'title': 'NBTC/ DLT GPS Tracker - Meitrack Group',
#     'link': 'https://www.meitrack.com/en/dlt-project-in-thailand/',
#     'snippet': 'To respond to the DLT policy issued by the Ministry of Transport of Thailand, Meitrack customized a magnetic card reader for its first 3G ...',
#     'date': 'Jul 11, 2022',
#     'position': 14},
#    {'title': "New medical certificate for Thai driver's license? - Thailand Motor Discussion - ASEAN NOW",
#     'link': 'https://aseannow.com/topic/1028279-new-medical-certificate-for-thai-drivers-license/',
#     'snippet': 'The form is pretty basic and probably just a word doc that all the clinics get from internet. Its not an official DLT document so the clinics could probably ...',
#     'position': 15},
#    {'title': 'Hell of a Journey Renewing My Driving License in Thailand - Jinnyology',
#     'link': 'https://www.jinnyology.com/post/hell-of-a-journey-renewing-my-drivers-license-in-thailand',
#     'snippet': 'I booked a 9:30 AM queue for March 16 at DLT Taling Chan office and had already finished my online training, which was basically a 1.5 hour long ...',
#     'date': 'Mar 16, 2023',
#     'position': 16},
#    {'title': "Thailand's DLT combats illegal driving license sales exposed by MP on Facebook | Thaiger",
#     'link': 'https://thethaiger.com/news/national/dlt-combats-illegal-driving-licence-sales-exposed-by-mp-on-facebook',
#     'snippet': "Thailand's Department of Land Transport (DLT) is taking action against individuals selling driver's licenses illegally, following a Move ...",
#     'date': 'Jun 9, 2023',
#     'position': 17},
#    {'title': "Walk-in renewal service for driver's licence resumes at DLT office - Nation Thailand",
#     'link': 'https://www.nationthailand.com/thailand/general/40020696',
#     'snippet': 'Applying for driving certificate in Thai or English. — Applying for or renewal of public vehicle licence. To renew a licence, the candidate ...',
#     'date': 'Oct 4, 2022',
#     'position': 18},
#    {'title': 'DLT Thai Licence Online App - English Language Instructions. (Only valid for newer licences with QR Code on the back) For those struggling with... | By Zed CM | Facebook',
#     'link': 'https://facebook.com/motogirlthailand/videos/dlt-thai-licence-online-app-english-language-instructions/752008621892795/',
#     'snippet': 'DLT Thai licence application, I made a video of my ...',
#     'date': 'Oct 28, 2019',
#     'attributes': {'Duration': '2:06', 'Posted': 'Oct 28, 2019'},
#     'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTy0Y3AMmPFE_uGzwPFaSS74KO-gclTlqteg44Snf5JEwYMH27qJRNmow',
#     'position': 19}],
#   'relatedSearches': [{'query': 'Dlt certification thailand test'},
#    {'query': 'Dlt certification thailand requirements'},
#    {'query': 'Dlt certification thailand online'},
#    {'query': 'Dlt certification thailand cost'},
#    {'query': 'DLT Thailand'}]}]
